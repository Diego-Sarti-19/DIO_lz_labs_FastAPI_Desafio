# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

# Construir URL de conexão com SQLAlchemy (modo mais seguro)
url = URL.create(
    drivername="postgresql+psycopg2",
    username="postgres",
    password="033145",     # sua senha real aqui
    host="localhost",
    port=5432,
    database="OnlineStore",
)

# Criar engine
engine = create_engine(url)

# Usar 'with' garante que a conexão será fechada automaticamente
with engine.connect() as conn:
    df = pd.read_sql("SELECT * FROM public.categories", conn)

print(df)
# Out:
#    category_id              name
# 0            1        Eletronics
# 1            2          Clothing
# 2            3  Home and Kitchen
# 3            6      Fashion Week
# 4            7        erotic oil

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL
import pandas as pd

url = URL.create(
    drivername="postgresql+psycopg2",
    username="workout",
    password="workout",
    host="localhost",
    port=5433,
    database="workoutdb",
)

engine = create_engine(url)

with engine.connect() as conn:
    df = pd.read_sql("SELECT 1 AS teste", conn)
print(df)
# Out:
#    teste
# 0      1
